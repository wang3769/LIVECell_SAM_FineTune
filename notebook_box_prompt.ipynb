# %%
"""
{
    "images": [
        {"id": 242287, "license": 4, "coco_url": "http://images.cocodataset.org/val2017/xxxxxxxxxxxx.jpg", "flickr_url": "http://farm3.staticflickr.com/2626/xxxxxxxxxxxx.jpg", "width": 426, "height": 640, "file_name": "xxxxxxxxx.jpg", "date_captured": "2013-11-15 02:41:42"},
    ],

    "annotations": [
        {"id": 125686, "category_id": 0, "iscrowd": 0, "segmentation": [[164.81, 417.51,......167.55, 410.64]], "image_id": 242287, "area": 42061.80340000001, "bbox": [19.23, 383.18, 314.5, 244.46]},
    ],

    "categories": [
        {"supercategory": "speaker","id": 0,"name": "echo"},
    ]
}
"""
# Out:
# '\n{\n    "images": [\n        {"id": 242287, "license": 4, "coco_url": "http://images.cocodataset.org/val2017/xxxxxxxxxxxx.jpg", "flickr_url": "http://farm3.staticflickr.com/2626/xxxxxxxxxxxx.jpg", "width": 426, "height": 640, "file_name": "xxxxxxxxx.jpg", "date_captured": "2013-11-15 02:41:42"},\n    ],\n\n    "annotations": [\n        {"id": 125686, "category_id": 0, "iscrowd": 0, "segmentation": [[164.81, 417.51,......167.55, 410.64]], "image_id": 242287, "area": 42061.80340000001, "bbox": [19.23, 383.18, 314.5, 244.46]},\n    ],\n\n    "categories": [\n        {"supercategory": "speaker","id": 0,"name": "echo"},\n    ]\n}\n'

# %%
from pycocotools.coco import COCO
coco_example = COCO("data/livecell/annotations/train.json")
coco_example.imgs.keys()
# Out:
# loading annotations into memory...
# Done (t=5.78s)
# creating index...
# index created!
# dict_keys([1, 133, 323, 498, 741, 1015, 1145, 1272, 1523, 1618, 1762, 1928, 2227, 2365, 2535, 2723, 3107, 3316, 3502, 3681, 3956, 4086, 4382, 4595, 4746, 4882, 5001, 5169, 5400, 5607, 5746, 5947, 6149, 6634, 6936, 7134, 7265, 7386, 7498, 7737, 7894, 8084, 8282, 8826, 9071, 9184, 9384, 9695, 9842, 9963, 10172, 10319, 10517, 10519, 10665, 10857, 11096, 11322, 11489, 11626, 11839, 12036, 12535, 12705, 13060, 13501, 13646, 13923, 14070, 14251, 14428, 14790, 14931, 15069, 15198, 15396, 15597, 15848, 15961, 16217, 16367, 16560, 16976, 17352, 17517, 17844, 17961, 18218, 18347, 18666, 18816, 19055, 19470, 19663, 19809, 19972, 20142, 20276, 20504, 20653, 20880, 21087, 21215, 21386, 21598, 21813, 21998, 22261, 22495, 22662, 22793, 22929, 23159, 23280, 23410, 23555, 23801, 23894, 24073, 24234, 24396, 24560, 24769, 24905, 25104, 25262, 25511, 25718, 25910, 26046, 26308, 26596, 26755, 27085, 27225, 27435, 27646, 27818, 27945, 28113, 28292, 28404, 28533, 28658, 28956, 29282, 29430, 29640, 29828, 30035, 30200, 30384, 30592, 31066, 31451, 31619, 31774, 31971, 32094, 32425, 32568, 32781, 32903, 33072, 33298, 33496, 33646, 33785, 33904, 34092, 34263, 34491, 34640, 34773, 35162, 
# %%
# Load categories for the given ids
ids = 1
cats = coco_example.loadCats(ids=ids)
print(cats)
# Out:
# [{'supercategory': 'cell', 'id': 1, 'name': 'cell'}]

# %%
category_ids = coco_example.getCatIds()
num_categories = len(category_ids)
print('number of categories: ',num_categories)
# Out:
# number of categories:  1

# %%
# Load images for the given ids
image_ids = coco_example.getImgIds()
image_id = image_ids[0]  # Change this line to display a different image
image_info = coco_example.loadImgs(image_id)
print(image_info)
# Out:
# [{'id': 1, 'width': 704, 'height': 520, 'file_name': 'BT474_Phase_A3_2_00d04h00m_3.tif', 'original_filename': 'BT474_Phase_A3_2_00d04h00m_3.png', 'url': 'https://darwin.v7labs.com/api/images/870028/original'}]

# %%
# Load annotations for the given ids
annotation_ids = coco_example.getAnnIds(imgIds=image_id)
annotations = coco_example.loadAnns(annotation_ids)
print(annotations)
# Out:
# [{'id': 2, 'image_id': 1, 'category_id': 1, 'segmentation': [[288.02, 305.63, 286.01, 298.87, 286.01, 295.4, 288.02, 290.1, 293.86, 287.91, 297.51, 287.73, 300.44, 289.01, 304.27, 292.48, 304.64, 295.04, 305.18, 297.77, 305.18, 300.7, 303.91, 302.52, 301.17, 305.26, 297.33, 307.45, 294.59, 307.45, 290.58, 308.0]], 'area': 307.4786000000313, 'bbox': [286.01, 287.73, 19.170000000000016, 20.269999999999982], 'iscrowd': 0}, {'id': 3, 'image_id': 1, 'category_id': 1, 'segmentation': [[271.22, 323.34, 267.93, 322.61, 266.29, 320.6, 265.38, 316.95, 263.37, 311.47, 263.0, 308.18, 265.19, 305.99, 267.93, 305.44, 270.31, 304.9, 274.32, 307.45, 275.42, 308.55, 280.9, 310.74, 283.09, 310.74, 283.45, 311.65, 283.09, 314.57, 280.35, 318.04, 277.06, 320.97, 274.87, 322.43]], 'area': 247.47555000009015, 'bbox': [263.0, 304.9, 20.44999999999999, 18.439999999999998], 'iscrowd': 0}, {'id': 4, 'image_id': 1, 'category_id': 1, 'segmentation': [[284.91, 279.88, 289.85, 281.52, 293.31, 281.52, 296.42, 282.8, 299.34, 285.72, 298.79, 286.82, 296.97, 287.55, 293.31, 288.28, 288.38, 289.74, 286.19, 293.94, 284.91, 294.3, 282.36, 294.12, 278.71, 294.12, 276.88, 293.94, 275.42, 291.02, 275.42, 286.45, 276.33, 282.44, 279.8, 277.87, 281.08, 277.51, 281.99, 277.14, 283.27, 277.14, 284.37, 278.24]], 'area': 245.22944999986794, 'bbox': [275.42, 277.14, 23.91999999999996, 17.160000000000025], 'iscrowd': 0}, {'id': 5, 'image_id': 1, 'category_id': 1, 'segmentation': [[260.86, 327.64, 258.19, 325.63, 255.25, 324.43, 253.51, 322.96, 251.37, 320.55, 249.5, 316.81, 248.17, 313.33, 246.96, 308.12, 247.1, 303.
# %%
# we can only choose one box at a time for prompt and thus one cell to target, this is related to how SAM designs
# yet this will require some alignment, luckily COCO sematic already took care of it
# ann["bbox"] → bounding box for that instance
# annToMask(ann) → pixel mask for that same instance
print("the box we should use for input is: ",annotations[0]['bbox'])
print("the corresponding gt mask is: ", coco_example.annToMask(annotations[0]).shape)
# Out:
# the box we should use for input is:  [286.01, 287.73, 19.170000000000016, 20.269999999999982]
# the corresponding gt mask is:  (520, 704)

# %% [markdown]
# The whole API concept is:\
#  get the Ids \
#  use the 1st as an example \
#  and then load the Ids

# %%
# Load category information for the given ID
catID = 1
print(coco_example.loadCats(ids=catID))

# Get image ID that satisfies the given filter conditions
imgId = coco_example.getImgIds(catIds=[catID])[0]
print(imgId)
# Out:
# [{'supercategory': 'cell', 'id': 1, 'name': 'cell'}]
# 196608

# %%
import torch
import numpy as np
from torch.utils.data import Dataset
from PIL import Image
from pycocotools.coco import COCO
from segment_anything.utils.transforms import ResizeLongestSide
import torch.nn.functional as F


class LiveCellSAMDataset(Dataset):
    def __init__(self, img_dir, ann_file, sam_model):
        self.img_dir = img_dir
        self.coco = COCO(ann_file)
        self.image_ids = list(self.coco.imgs.keys())

        self.transform = ResizeLongestSide(1024)
        self.pixel_mean = sam_model.pixel_mean
        self.pixel_std = sam_model.pixel_std

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]
        img_info = self.coco.imgs[image_id]

        # ---------- load image ----------
        image = Image.open(
            f"{self.img_dir}/{img_info['file_name']}"
        ).convert("RGB")
        image = np.array(image)
        H, W = image.shape[:2]

        # ---------- load annotations ----------
        ann_ids = self.coco.getAnnIds(imgIds=image_id)
        anns = self.coco.loadAnns(ann_ids)

        # pick ONE instance
        ann = anns[np.random.randint(len(anns))]

        gt_mask = self.coco.annToMask(ann)      # [H,W]
        x, y, w, h = ann["bbox"]
        box = np.array([[x, y, x + w, y + h]])  # [1,4]

        # ---------- resize ----------
        image = self.transform.apply_image(image)
        gt_mask = self.transform.apply_image(gt_mask)
        box = self.transform.apply_boxes(box, (H, W))

        # ---------- pad to 1024 ----------
        new_h, new_w = image.shape[:2]
        pad_h = 1024 - new_h
        pad_w = 1024 - new_w

        image = torch.from_numpy(image).permute(2, 0, 1).float() / 255.0
        gt_mask = torch.from_numpy(gt_mask).unsqueeze(0).float()
        box = torch.from_numpy(box).float()

        image = F.pad(image, (0, pad_w, 0, pad_h))
        gt_mask = F.pad(gt_mask, (0, pad_w, 0, pad_h))

        # ---------- normalize ----------
        #image = (image - self.pixel_mean) / self.pixel_std

        return {
            "image": image,          # [3,1024,1024]
            "mask": gt_mask,         # [1,1024,1024]
            "box": box,              # [1,4]
            "image_id": image_id,
        }

# %%
import torch
from torch.utils.data import DataLoader
from segment_anything import sam_model_registry
from tqdm import tqdm

device = "cuda"

sam = sam_model_registry["vit_b"](checkpoint="sam/sam_vit_b_01ec64.pth")
sam = sam.to(device)

dataset = LiveCellSAMDataset(
    img_dir="data/livecell/images/train",
    ann_file="data/livecell/annotations/train.json",
    sam_model=sam
)
# Out:
# loading annotations into memory...
# Done (t=5.27s)
# creating index...
# index created!

# %%
print("the image shape is: ",dataset[0]["image"].shape)
print("the mask shape is: ",dataset[0]["mask"].shape)
print("the box shape is: ",dataset[0]["box"].shape)
# Out:
# the image shape is:  torch.Size([3, 1024, 1024])
# the mask shape is:  torch.Size([1, 1024, 1024])
# the box shape is:  torch.Size([1, 4])

# %%
import matplotlib.pyplot as plt

batch = dataset[0]
img = batch["image"].permute(1,2,0).cpu()
mask = batch["mask"][0].cpu()
box = batch["box"][0].cpu()

plt.imshow(img)
plt.imshow(mask, alpha=0.4)

x0,y0,x1,y1 = box
plt.gca().add_patch(
    plt.Rectangle((x0,y0), x1-x0, y1-y0, fill=False, color="red")
)

plt.title("Box–Mask Alignment Check")
plt.axis("off")
plt.show()

# %%
print("the image directory is: ", f'{dataset.img_dir}')
print("the number of images is: ", f'{len(dataset)}')
print("the number of image IDs is: ", f'{len(dataset.image_ids)}')

print("---------------------------------------------------------")

print("the sam model pixel mean is: ", f'{len(dataset.pixel_mean)}')
print("the sam model pixel std is: ", f'{len(dataset.pixel_std)}')
# Out:
# the image directory is:  data/livecell/images/train
# the number of images is:  3253
# the number of image IDs is:  3253
# ---------------------------------------------------------
# the sam model pixel mean is:  3
# the sam model pixel std is:  3

# %%
image_id = dataset.image_ids[0]
img_info = dataset.coco.imgs[image_id]
image = Image.open(f"{dataset.img_dir}/{img_info['file_name']}").convert("RGB")
image = np.array(image)

H, W = image.shape[:2]
print("for image index at 0, the image dimension is: ", f'{image.shape}')
print("such that (H, W) is ", f'{H, W}')
# Out:
# for image index at 0, the image dimension is:  (520, 704, 3)
# such that (H, W) is  (520, 704)

# %%
ann_ids = dataset.coco.getAnnIds(imgIds=image_id)
anns = dataset.coco.loadAnns(ann_ids) # loadAnns will load up all info in annotation

masks = []
for ann in anns:
    masks.append(dataset.coco.annToMask(ann)) # anntoMask will load up binary mask

print("annotations associated with image are converted to a binary mask list : ", f'{len(masks)}')
print("each mask in the list has dimension of : ", f'{masks[0].shape}')

masks = torch.from_numpy(np.stack(masks)).to(torch.uint8)  # [N,H,W]
print("this list need to be a torch tensor with dimensions of : ", f'{masks.shape}')
# Out:
# annotations associated with image are converted to a binary mask list :  130
# each mask in the list has dimension of :  (520, 704)
# this list need to be a torch tensor with dimensions of :  torch.Size([130, 520, 704])

# %%
inst_idx = torch.randint(0, masks.shape[0], (1,)).item() # pick one out of 130 to use it to sample point
gt_mask = masks[inst_idx]                                   # [H,W]
print("pick a gt_mask from all masks with the shape of: ", f'{gt_mask.shape}')
# Out:
# pick a gt_mask from all masks with the shape of:  torch.Size([520, 704])

# %%
image = dataset.transform.apply_image(image)
print("after transform, the image dimension is: ", f'{image.shape}')
gt_mask = dataset.transform.apply_image(gt_mask.numpy())
print("after transform, the mask dimension is: ", f'{gt_mask.shape}')
# Out:
# after transform, the image dimension is:  (756, 1024, 3)
# after transform, the mask dimension is:  (756, 1024)

# %%
image = torch.from_numpy(image).permute(2, 0, 1).float()
print("after permute, the image dimension to place color channel in the fornt", f'{image.shape}')
# Out:
# after permute, the image dimension to place color channel in the fornt torch.Size([3, 756, 1024])

# %%
print("after transform, the image dimension is: ", f'{dataset[0]["image"].shape}')
print("after transform, the mask dimension is: ", f'{dataset[0]["mask"].shape}')
# Out:
# after transform, the image dimension is:  torch.Size([3, 1024, 1024])
# after transform, the mask dimension is:  torch.Size([1, 1024, 1024])

# %%
def iou_loss(logits, targets, eps=1e-6):
    """
    logits: [B,1,H,W] raw SAM outputs
    targets: [B,1,H,W] binary {0,1}
    """
    probs = torch.sigmoid(logits)

    intersection = (probs * targets).sum(dim=(2, 3))
    union = probs.sum(dim=(2, 3)) + targets.sum(dim=(2, 3)) - intersection

    iou = (intersection + eps) / (union + eps)
    loss = 1 - iou

    return loss.mean()

# %%
from torch.utils.data import DataLoader
from tqdm import tqdm


# freeze everything except mask decoder
for p in sam.image_encoder.parameters():
    p.requires_grad = False
for p in sam.prompt_encoder.parameters():
    p.requires_grad = False

optimizer = torch.optim.AdamW(
    sam.mask_decoder.parameters(), lr=1e-5
)

loader = DataLoader(dataset, batch_size=1, shuffle=True) # very useful not just for convenience

# %%
sam.train()

for step, batch in enumerate(loader):
    img = batch["image"].to(device)      # [B,3,1024,1024]
    gt_mask = batch["mask"].to(device)   # [B,1,1024,1024]
    box = batch["box"].to(device)        # [B,1,4]

    with torch.no_grad():
        image_embedding = sam.image_encoder(img)

    sparse, dense = sam.prompt_encoder(
        points=None,
        boxes=box,
        masks=None
    )

    low_res_masks, _ = sam.mask_decoder(
        image_embedding,
        image_pe=sam.prompt_encoder.get_dense_pe().to(device),
        sparse_prompt_embeddings=sparse,
        dense_prompt_embeddings=dense,
        multimask_output=False
    )

    # upsample prediction
    pred_mask = torch.nn.functional.interpolate(
        low_res_masks,
        size=(1024,1024),
        mode="bilinear",
        align_corners=False
    )

    loss = iou_loss(pred_mask, gt_mask)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    if step % 100 == 0:
        print(f"step {step}, loss {loss.item():.4f}")
    break
# Out:
# step 0, loss 0.2187

# %%
# why 256 x 256? because Image encoder outputs features at 1/16 resolution
# yet the output is just logits for cross entropy convenience we need to look at prob
mask_prob = torch.sigmoid(low_res_masks)
print(mask_prob)
# Out:
# tensor([[[[4.1868e-13, 1.5989e-11, 8.7188e-13,  ..., 2.8473e-11,
#            9.8455e-14, 1.8372e-11],
#           [4.4970e-12, 7.0390e-13, 3.3503e-11,  ..., 1.6308e-14,
#            7.1858e-13, 9.1471e-16],
#           [1.7297e-12, 1.0891e-10, 2.1482e-11,  ..., 8.8617e-10,
#            2.2444e-12, 2.8284e-11],
#           ...,
#           [3.2472e-13, 6.2590e-13, 7.6128e-12,  ..., 1.6971e-13,
#            1.7028e-12, 2.9699e-13],
#           [8.3408e-14, 1.0949e-11, 2.8750e-13,  ..., 6.4127e-11,
#            2.2258e-13, 8.6632e-12],
#           [3.3288e-12, 2.6060e-12, 9.1329e-12,  ..., 4.0635e-12,
#            1.3196e-11, 5.7576e-13]]]], device='cuda:0',
#        grad_fn=<SigmoidBackward0>)

# %%
import torch.nn.functional as F

# low_res_masks: [B, 1, 256, 256]
pred_logits = low_res_masks

# probability mask
pred_prob = torch.sigmoid(pred_logits)

# upsample to image size (1024x1024)
pred_prob_up = F.interpolate(
    pred_prob,
    size=(1024, 1024),
    mode="bilinear",
    align_corners=False
)

# binary mask (for evaluation / overlay)
pred_mask = (pred_prob_up > 0.5).float()

# %%
import numpy as np

# image: [B,3,1024,1024]
img_np = img[0].detach().cpu().permute(1, 2, 0).numpy()

# gt_mask: [B,1,1024,1024]
gt_mask_np = gt_mask[0, 0].detach().cpu().numpy()

# pred mask
pred_mask_np = pred_mask[0, 0].detach().cpu().numpy()
pred_prob_np = pred_prob_up[0, 0].detach().cpu().numpy()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 4, figsize=(18, 5))

# original image
axs[0].imshow(img_np)
axs[0].set_title("Original Image")
axs[0].axis("off")

# ground truth mask
axs[1].imshow(gt_mask_np, cmap="gray")
axs[1].set_title("Ground Truth Mask")
axs[1].axis("off")

# predicted probability heatmap
axs[2].imshow(pred_prob_np, cmap="jet")
axs[2].set_title("Predicted Mask (Prob)")
axs[2].axis("off")

# overlay prediction on image
axs[3].imshow(img_np)
axs[3].imshow(pred_mask_np, alpha=0.5, cmap="Reds")
axs[3].set_title("Prediction Overlay")
axs[3].axis("off")

plt.tight_layout()
plt.show()

# %%
# flatten for safety
pred_flat = pred_mask.view(-1)
gt_flat = gt_mask.view(-1)

intersection = (pred_flat * gt_flat).sum()
union = pred_flat.sum() + gt_flat.sum() - intersection

iou = intersection / (union + 1e-6)
dice = 2 * intersection / (pred_flat.sum() + gt_flat.sum() + 1e-6)

print(f"IoU  : {iou.item():.4f}")
print(f"Dice : {dice.item():.4f}")
# Out:
# IoU  : 0.8272
# Dice : 0.9054

# %% [markdown]
# The following content is about understanding SAM

# %%
import torch

def measure(fn, *args, **kwargs):
    start = torch.cuda.Event(enable_timing=True)
    end = torch.cuda.Event(enable_timing=True)

    torch.cuda.synchronize()
    start.record()
    out = fn(*args, **kwargs)
    end.record()
    torch.cuda.synchronize()

    return out, start.elapsed_time(end)  # milliseconds

# %%
sam.train()

encoder_times = []
decoder_times = []

for step, batch in enumerate(loader):
    optimizer.zero_grad(set_to_none=True)

    # ---- load batch ----
    img = batch["image"].to(device)      # [B,3,1024,1024]
    gt_mask = batch["mask"].to(device)   # [B,1,1024,1024]
    box = batch["box"].to(device)        # [B,1,4]

    # ---- normalize image ----
    img = (img - sam.pixel_mean) / sam.pixel_std

    # ---- image encoder (timed, frozen) ----
    with torch.no_grad():
        image_embedding, t_enc = measure(
            sam.image_encoder,
            img
        )

    # ---- prompt encoder (cheap, no timing needed) ----
    sparse, dense = sam.prompt_encoder(
        points=None,
        boxes=box,
        masks=None
    )

    # ---- mask decoder (timed, trainable) ----
    (low_res_masks, _), t_dec = measure(
        sam.mask_decoder,
        image_embedding,
        sam.prompt_encoder.get_dense_pe().to(device),
        sparse,
        dense,
        False
    )

    # ---- upsample prediction ----
    pred_mask = torch.nn.functional.interpolate(
        low_res_masks,
        size=(1024, 1024),
        mode="bilinear",
        align_corners=False
    )

    # ---- loss ----
    loss = iou_loss(pred_mask, gt_mask)

    # ---- backward ----
    loss.backward()
    optimizer.step()

    # ---- record timings ----
    encoder_times.append(t_enc)
    decoder_times.append(t_dec)

    # ---- logging ----
    if step % 100 == 0:
        print(
            f"step {step:05d} | "
            f"loss {loss.item():.4f} | "
            f"enc {t_enc:.1f} ms | "
            f"dec {t_dec:.1f} ms"
        )
    break
# Out:
# step 00000 | loss 0.8821 | enc 286.9 ms | dec 3.4 ms

# %%
"""
Why image encoder dominates:

4096 tokens

12–32 transformer blocks

Each block has:

    QKV projections

    Attention

    MLP

Memory movement dominates arithmetic
"""
# Out:
# '\nWhy image encoder dominates:\n\n4096 tokens\n\n12–32 transformer blocks\n\nEach block has:\n\n    QKV projections\n\n    Attention\n\n    MLP\n\nMemory movement dominates arithmetic\n'

# %%
"""
Memory footprint per image
Token memory alone (SAM ViT-B): 4096 × 768 × 2 bytes ≈ 6 MB

    Tokens: 64 × 64 = 4096

    Embedding dim: 768

    dtype: FP16 (best case)

~6–8× token tensor size per layer, For ViT-B (12 layers): 6 MB × 6 × 12 ≈ 432 MB
    batch = 8 then 💀 OOM on most GPUs like 5090

"""
# Out:
# '\nMemory footprint per image\nToken memory alone (SAM ViT-B): 4096 × 768 × 2 bytes ≈ 6 MB\n\n    Tokens: 64 × 64 = 4096\n\n    Embedding dim: 768\n\n    dtype: FP16 (best case)\n\n~6–8× token tensor size per layer, For ViT-B (12 layers): 6 MB × 6 × 12 ≈ 432 MB\n    batch = 8 then 💀 OOM on most GPUs like 5090\n\n'

# %%
"""
Why ViT-H is impractical: 32 x 64^2 x 1280

O(Layers × Tokens² × Dim)

    More layers

    Larger embedding

~4–5× latency

~3–4× memory

"""
# Out:
# '\nWhy ViT-H is impractical: 32 x 64^2 x 1280\n\nO(Layers × Tokens² × Dim)\n\n    More layers\n\n    Larger embedding\n\n~4–5× latency\n\n~3–4× memory\n\n'

# %%
"""
Design tradeoff:

SAM trades throughput for flexibility.

This is why:

    SAM is terrible for “segment 130 cells at once”

    Excellent for interactive annotation

    Often paired with a detector in production
"""
# Out:
# '\nDesign tradeoff:\n\nSAM trades throughput for flexibility.\n\nThis is why:\n\n    SAM is terrible for “segment 130 cells at once”\n\n    Excellent for interactive annotation\n\n    Often paired with a detector in production\n'

# %%
"""
Resolution ↑ → Tokens ↑ → Attention explodes
Depth ↑ → Memory explodes
Width ↑ → Compute + memory explode
Batch ↑ → Everything explodes
"""
# Out:
# '\nResolution ↑ → Tokens ↑ → Attention explodes\nDepth ↑ → Memory explodes\nWidth ↑ → Compute + memory explode\nBatch ↑ → Everything explodes\n'
